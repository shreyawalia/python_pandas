# %%
import pandas as pd

# %%
#we can replace custom missing values while loading the data itself.
#we can pass a list of arguements that wecwant to be treated as missing values
na_vals = ['NA', 'Missing']

# %%
#specify arguements na_val which considers the values in list as NaNs 
df = pd.read_csv("data/survey_results_public.csv", index_col = 'Respondent', na_values = na_vals)
schema_df = pd.read_csv('data/survey_results_schema.csv', index_col='Column')

# %%
df
# Out:
#                                                    MainBranch Hobbyist  \
# Respondent
# 1                      I am a student who is learning to code      Yes
# 2                      I am a student who is learning to code       No
# 3           I am not primarily a developer, but I write co...      Yes
# 4                              I am a developer by profession       No
# 5                              I am a developer by profession      Yes
# ...                                                       ...      ...
# 88377                                                     NaN      Yes
# 88601                                                     NaN       No
# 88802                                                     NaN       No
# 88816                                                     NaN       No
# 88863                                                     NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# ...

# %%
df['YearsCode'].head(10)
# Out:
# Respondent
# 1       4
# 2     NaN
# 3       3
# 4       3
# 5      16
# 6      13
# 7       6
# 8       8
# 9      12
# 10     12
# Name: YearsCode, dtype: object

# %%
df['YearsCode'].mean() #error as NaN
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-63967e025d37> in <module>
# ----> 1 df['YearsCode'].mean() #error as NaN
#
# c:\users\walia\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, **kwargs)
#   11213         if level is not None:
#   11214             return self._agg_by_level(name, axis=axis, level=level, skipna=skipna)
# > 11215         return self._reduce(
#   11216             f, name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11217         )
#
# c:\users\walia\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3890                 )
#    3891             with np.errstate(all="ignore"):
# ...

# %%
df['YearsCode'].astype(float) #error as it has string values too
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-a03833e6c8db> in <module>
# ----> 1 df['YearsCode'].astype(float)
#
# c:\users\walia\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5695         else:
#    5696             # else, only a single dtype is given
# -> 5697             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5698             return self._constructor(new_data).__finalize__(self)
#    5699
#
# c:\users\walia\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
# ...

# %%
#seeing all unique values
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38', '31',
#        '37', 'More than 50 years', '29', '44', '45', '48', '46', '43',
#        '47', '49'], dtype=object)

# %%
#replacing string values with numbers
df['YearsCode'].replace('Less than 1 year', 0, inplace = True)
df['YearsCode'].replace('More than 50 years', 51, inplace = True)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 11.662114216834588

# %%
df['YearsCode'].median()
# Out:
# 9.0
